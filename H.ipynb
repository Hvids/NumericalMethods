# %%
import numpy as np

# %%
v = np.array(
        [[1,5]]
    
)
u = np.array(
    [[5,1]]
)
v = v.T
u= u.T

# %%
H = np.eye(u.shape[0]) - 2*np.dot(u,u.T)/(np.dot(u.T,u))

# %%
v_ = np.dot(H,v)
v_
# Out:
# array([[-2.84615385],
#        [ 4.23076923]])

# %%
v_plot = np.hstack((np.zeros(shape=v.shape),v))
# np.zeros(shape=(2,1))
u_plot = np.hstack((np.zeros(shape=u.shape),u))
v_h_plot = np.hstack((np.zeros(shape=u.shape),v_))

# %%
import matplotlib.pyplot as plt

# %%
plt.subplots(ncols=1,nrows=1,figsize=(12,6))
plt.plot(v_plot[0],v_plot[1],color="red",label='v')
plt.plot(u_plot[0],u_plot[1], color='blue',label='u')
plt.plot([0,-1],[0,5],color='grey', label='plane')
plt.plot(v_h_plot[0],v_h_plot[1], color='black',label='v_H')
plt.legend()
plt.show()
