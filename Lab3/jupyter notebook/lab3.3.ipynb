# %%
import sys
sys.path.append('../../Lab1/')
sys.path.append('..')

# %%
import sympy 
import matplotlib.pyplot as plt
import numpy as np
from methodLUP import solve_LUP
from polynomial import Polynomial
# %matplotlib inline

# %%
x_vec = [0.1, 0.5, 0.9, 1.3, 1.7, 2.1]
y_vec = [-2.3026, -0.69315, -0.10536, 0.26236, 0.53063, 0.74194]

# %%
k = 1
pol = Polynomial(k)
pol.make(y_vec,x_vec)
print(f'Y = {y_vec}')
print(f'X = {x_vec}')
print(f'Полином {k}-й степени:')
pol.print_polynom()
print(f'Сумма квадратов ошибок = {pol.mse}')
x_pol = np.arange(x_vec[0]-1,x_vec[-1]+1,0.1)
y_pol = list(map(lambda xi: pol.calc_point(xi),x_pol))

plt.title('Графики полинома и табличных значений функции')

plt.scatter(x_vec,y_vec, color = "blue", label='y')
plt.plot(x_pol,y_pol,color = "red", label=f'F{k}')
plt.legend()
# Out:
# Y = [-2.3026, -0.69315, -0.10536, 0.26236, 0.53063, 0.74194]
# X = [0.1, 0.5, 0.9, 1.3, 1.7, 2.1]
# Полином 1-й степени:
# 1.37584⋅x - 1.774454
# Сумма квадратов ошибок = 0.985360401120000

# %%
k = 2
pol = Polynomial(k)
pol.make(y_vec,x_vec)
print(f'Y = {y_vec}')
print(f'X = {x_vec}')
print(f'Полином {k}-й степени:')
pol.print_polynom()
print(f'Сумма квадратов ошибок = {pol.mse}')
x_pol = np.arange(x_vec[0]-1,x_vec[-1]+1,0.1)
y_pol = list(map(lambda xi: pol.calc_point(xi),x_pol))

plt.title('Графики полинома и табличных значений функции')

plt.scatter(x_vec,y_vec, color = "blue", label='y')
plt.plot(x_pol,y_pol,color = "red", label=f'F{k}')
plt.legend()
# Out:
# Y = [-2.3026, -0.69315, -0.10536, 0.26236, 0.53063, 0.74194]
# X = [0.1, 0.5, 0.9, 1.3, 1.7, 2.1]
# Полином 2-й степени:
#               2
# - 0.92285491⋅x  + 3.4061208⋅x - 2.46044282
# Сумма квадратов ошибок = 0.171399416734286
